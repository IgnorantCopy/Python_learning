# %%
import time as t

import matplotlib.pyplot as mp
import numpy as np


def hs(start, end, step, func, name):
    x = np.arange(float(start), float(end), float(step))
    if func == '一次函数' or func == '1':
        k1 = input('一次项系数：')
        b1 = input('常数项：')
        mp.plot(x, float(k1) * x + float(b1), label=str(name))
    elif func == '二次函数' or func == '2':
        a2 = input('二次项系数：')
        b2 = input('一次项系数：')
        c2 = input('常数项：')
        mp.plot(x, float(a2) * x ** 2 + float(b2) * x + float(c2), label=str(name))
    elif func == '三次函数' or func == '3':
        a3 = input('三次项系数：')
        b3 = input('二次项系数：')
        c3 = input('一次项系数：')
        d3 = input('常数项：')
        mp.plot(x, float(a3) * x ** 3 + float(b3) * x ** 2 + float(c3) * x + float(d3), label=str(name))
    elif func == '四次函数' or func == '4':
        a4 = input('四次项系数：')
        b4 = input('三次项系数：')
        c4 = input('二次项系数：')
        d4 = input('一次项系数：')
        e4 = input('常数项：')
        mp.plot(x, float(a4) * x ** 4 + float(b4) * x ** 3 + float(c4) * x ** 2 + float(d4) * x + float(e4),
                label=str(name))
    elif func == '五次函数' or func == '5':
        a5 = input('五次项系数：')
        b5 = input('四次项系数：')
        c5 = input('三次项系数：')
        d5 = input('二次项系数：')
        e5 = input('一次项系数：')
        f5 = input('常数项：')
        mp.plot(x, float(a5) * x ** 5 + float(b5) * x ** 4 + float(c5) * x ** 3 + float(d5) * x ** 2 + float(
            e5) * x + float(f5), label=str(name))
    elif func == '指数函数' or func == '6':
        k6 = input('函数前系数：')
        a6 = input('底数：')
        a6_ = input('幂一次系数：')
        b6_ = input('幂常数：')
        b6 = input('常数项：')
        if a6 > 0 and a6 != 1:
            if a6 == 'e':
                mp.plot(x, float(k6) * np.exp(float(a6_) * x + float(b6_)) + float(b6), label=str(name))
            else:
                mp.plot(x, float(k6) * float(a6) ** (float(a6_) * x + float(b6_)) + float(b6), label=str(name))
        else:
            print('具有数学错误！')
            hs(starts, ends, steps, typet, name=tt)
    elif func == '对数函数' or func == '7':
        a7 = input('底数：')
        b7_1 = input('真数一次项系数：')
        b7_2 = input('真数常数项：')
        c7 = input('常数项：')
        if a7 > 0 and a7 != 1:
            if a7 == 'e':
                mp.plot(x, np.log(float(b7_1) * x + float(b7_2)) + float(c7), label=str(name))
            else:
                mp.plot(x, np.log(float(b7_1) * x + float(b7_2)) / np.log(float(a7)) + float(c7), label=str(name))
        else:
            print('具有数学错误！')
            hs(starts, ends, steps, typet, name=tt)


print("欢迎使用几何画板1.0！")
print("本程序支持以下功能：函数图像绘制 （编号为一）、几何（编号为二）")
print("函数图像绘制支持：一至五次函数（编号为1~5）、指数函数（编号为6）、对数函数（编号为7）")
print("几何支持：直线、多边形")
t.sleep(1)
pd = input('选择一级功能：')
if pd == '函数图像绘制':
    typet = input('函数类型：')
    starts = float(input('开始值：'))
    ends = float(input('结束值：'))
    steps = float(input('步长（步长越小，精确度越高）：'))
    tt = input('函数名：')
    hs(starts, ends, steps, typet, name=tt)
    while 1:
        jx = input('是否添加另一函数:')
        if jx == '是' or jx == '1':
            typet = input('函数类型：')
            tt = input('函数名：')
            hs(starts, ends, steps, typet, name=tt)
        else:
            mp.title("Geometer's Sketchpad")
            mp.legend()
            mp.show()
            break
elif pd == '几何':
    password1 = input('请输入解锁密码：')
    if password1 != '273441850625':
        print('密码错误！请1min后重试！')
        t.sleep(10)
        print('10秒')
        t.sleep(10)
        print('20秒')
        t.sleep(10)
        print('30秒')
        t.sleep(10)
        print('40秒')
        t.sleep(10)
        print('50秒')
        t.sleep(10)
        print('60秒到！')
        print('你竟然真的等了60秒！')
        print('看在你等得这么辛苦的份上，我就告诉你密码吧：273441850625')
        password2 = input('请输入解锁密码：')
        while 1:
            if password2 == '273441850625':
                print('成功解锁！')
                break
            else:
                continue
        print('很遗憾地告诉你，本功能尚未开发，敬请期待几何画板2.0！')
    else:
        print('什么！你竟然知道密码！')
        print('但是很遗憾地告诉你，本功能尚未开发，敬请期待几何画板2.0！')
# Out:
# 欢迎使用几何画板1.0！
# 本程序支持以下功能：函数图像绘制 （编号为一）、几何（编号为二）
# 函数图像绘制支持：一至五次函数（编号为1~5）、指数函数（编号为6）、对数函数（编号为7）
# 几何支持：直线、多边形
# D:\codes\Python_learning\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\codes\Python_learning\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\codes\Python_learning\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20989 (\N{CJK UNIFIED IDEOGRAPH-51FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\codes\Python_learning\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
